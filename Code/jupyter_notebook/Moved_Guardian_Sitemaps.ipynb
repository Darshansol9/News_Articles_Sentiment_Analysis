# %%
import os
import shutil

# %%
if __name__ == '__main__':
    path = r'C:\Users\Darshan\Music\raman_kannan\NLP\guardian_sitemaps'
    os.chdir(path)
    for y in os.listdir('.'):
        if(y == '2008'):
            continue
        path_ = path + '\\'+y
        os.chdir(path_)
        for m in os.listdir('.'):
            path_ = path_ + '\\'+m
            print(f'Subfolder path {path_}')
            os.chdir(path_)
            for sitemap in os.listdir('.'):
                if(sitemap.find('Sitemap') == 0):
                    source = path_+'\\'+sitemap
                    dest = r'C:\Users\Darshan\Music\raman_kannan\NLP\G_sitemaps'
                    shutil.move(source,dest)
                    print(f'Moved {sitemap}')
                    
            path_ = path + '\\'+y
                    
    print('Request Completed')
# Out:
# Subfolder path C:\Users\Darshan\Music\raman_kannan\NLP\guardian_sitemaps\2009\01
# Moved Sitemap-2009-01.json
# Subfolder path C:\Users\Darshan\Music\raman_kannan\NLP\guardian_sitemaps\2009\02
# Moved Sitemap-2009-02.json
# Subfolder path C:\Users\Darshan\Music\raman_kannan\NLP\guardian_sitemaps\2009\03
# Moved Sitemap-2009-03.json
# Subfolder path C:\Users\Darshan\Music\raman_kannan\NLP\guardian_sitemaps\2009\04
# Moved Sitemap-2009-04.json
# Subfolder path C:\Users\Darshan\Music\raman_kannan\NLP\guardian_sitemaps\2009\05
# Moved Sitemap-2009-05.json
# Subfolder path C:\Users\Darshan\Music\raman_kannan\NLP\guardian_sitemaps\2009\06
# Moved Sitemap-2009-06.json
# Subfolder path C:\Users\Darshan\Music\raman_kannan\NLP\guardian_sitemaps\2009\07
# Moved Sitemap-2009-07.json
# Subfolder path C:\Users\Darshan\Music\raman_kannan\NLP\guardian_sitemaps\2009\08
# Moved Sitemap-2009-08.json
# Subfolder path C:\Users\Darshan\Music\raman_kannan\NLP\guardian_sitemaps\2009\09
# ...
